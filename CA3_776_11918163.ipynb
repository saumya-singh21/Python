# %% [markdown]
# # COVID-19 ASSINGNMENT

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("C:/Users/Lenovo/Desktop/Covid.csv")
data.head()
# Out:
#    Unnamed: 0    1  Patient Number State Patient Number Date Announced  \
# 0           0  NaN             NaN                  NaN            NaN
# 1           1  2.0             1.0             KL-TS-P1     30/01/2020
# 2           2  3.0             2.0             KL-AL-P1     02/02/2020
# 3           3  4.0             3.0             KL-KS-P1     03/02/2020
# 4           4  5.0             4.0                DL-P1     02/03/2020
#
#   Age Bracket Gender             Detected City Detected District  \
# 0         NaN    NaN                       NaN               NaN
# 1          20      F                  Thrissur          Thrissur
# 2         NaN    NaN                 Alappuzha         Alappuzha
# 3         NaN    NaN                 Kasaragod         Kasaragod
# 4          45      M  East Delhi (Mayur Vihar)        East Delhi
#
#   Detected State  ...                                           Source_2  \
# ...

# %%
sub_data = data[["Gender","Detected State","Age Bracket"]]
sub_data.head()
# Out:
#   Gender Detected State Age Bracket
# 0    NaN            NaN         NaN
# 1      F         Kerala          20
# 2    NaN         Kerala         NaN
# 3    NaN         Kerala         NaN
# 4      M          Delhi          45

# %%
sub_data.shape
# Out:
# (2072, 3)

# %%
sub_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2072 entries, 0 to 2071
# Data columns (total 3 columns):
# Gender            742 non-null object
# Detected State    1723 non-null object
# Age Bracket       618 non-null object
# dtypes: object(3)
# memory usage: 48.7+ KB

# %% [markdown]
# # drop NA

# %%
sub_data.dropna(subset = ['Detected State','Gender'],inplace=True)
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
sub_data.head()
# Out:
#    Gender Detected State Age Bracket
# 1       F         Kerala          20
# 4       M          Delhi          45
# 5       M      Telangana          24
# 6       M      Rajasthan          69
# 21      F      Rajasthan          70

# %%
sub_data["Age Bracket"].fillna('0',inplace=True)
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\pandas\core\generic.py:6287: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)

# %%
def assign_age(x):
    if len(x)>3:
        x1,x2 = x.split('-')
        return str((int(x1)+int(x2))/2).split('.')[0]
    else:
        return x

# %%
sub_data['Age Bracket'] = sub_data["Age Bracket"].apply(assign_age)
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
sub_data["Age Bracket"] = sub_data['Age Bracket'].astype(int)
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
sub_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 742 entries, 1 to 1663
# Data columns (total 3 columns):
# Gender            742 non-null object
# Detected State    742 non-null object
# Age Bracket       742 non-null int32
# dtypes: int32(1), object(2)
# memory usage: 20.3+ KB

# %%
age_mean = int(sub_data[sub_data["Age Bracket"]!=0]['Age Bracket'].mean())

# %%
sub_data["Age Bracket"].replace(0,age_mean,inplace=True)
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\pandas\core\generic.py:6786: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)

# %%
sub_data.head()
# Out:
#    Gender Detected State  Age Bracket
# 1       F         Kerala           20
# 4       M          Delhi           45
# 5       M      Telangana           24
# 6       M      Rajasthan           69
# 21      F      Rajasthan           70

# %%
plt.figure(figsize=(25,10))
plt.xticks(rotation=45)
sns.set(style="white")
sns.barplot(x="Detected State",y='Age Bracket',data=sub_data,hue='Gender',ci=None ,color='b' )
plt.legend(["Female","Male"],prop={'size':15})
plt.xlabel("Affected States",fontdict={"size":15})
plt.ylabel("Average age of Affected Male/Females",fontdict={"size":15})
plt.title("Average Age of affected Males/Females in all states in india",fontdict={"size":25})
# Out:
# Text(0.5, 1.0, 'Average Age of affected Males/Females in all states in india')

# %%
plt.figure(figsize=(25,10))
sns.set(style="darkgrid")
plt.xticks(rotation=30)
sns.boxplot(x="Detected State",y='Age Bracket',data=sub_data,hue='Gender',color='y',palette="deep")
plt.legend(["Female","Male"],prop={'size':25})
plt.xlabel("Affected States",fontdict={"size":15})
plt.ylabel("Average age of Affected Male/Females",fontdict={"size":15})
plt.title("Average Age of affected Males/Females in all states in india",fontdict={"size":25})
# Out:
# Text(0.5, 1.0, 'Average Age of affected Males/Females in all states in india')

# %% [markdown]
# #the above grapph shows the males and females affected for each state.  average age of females are affected are around 45 and average age of male are around 38 .affected males are younger then females
